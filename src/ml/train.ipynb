# %%
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("khadijaelabbioui/agrivision-unified-plant-disease-18-classes")

print("Path to dataset files:", path)

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
DRIVE_SAVE_PATH = "/content/drive/MyDrive/YOLO_results"
model = YOLO('yolov8n.pt')
path_to_yaml = os.path.join(DATASET_PATH, "data.yaml")
results = model.train(
    data=path_to_yaml,
    epochs=30,
    imgsz=640,
    batch=8,
    name='parking_yolov8',
    project=DRIVE_SAVE_PATH,
    device=0 ,
    workers=2,
    exist_ok=True
)
