# %%
import os

# %%
path = "../data/"
print(os.listdir(path))
# Out:
# ['station', 'silver', 'sources.txt', 'bronze', 'pepper.v1i.folder.zip', 'archive.zip', 'frame', 'pepper.v1i.yolov8-obb.zip', 'raw']
